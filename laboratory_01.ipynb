# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator

# %%
def fun1(x) -> np.ndarray:
    # Sphere function
    return np.sum(x**2)

def draw_fun1(X, Y):
    return X**2 + Y**2

def grad_fun1(x):
    return 2*x

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
Z = draw_fun1(X, Y)

surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, alpha=0.5)

xs = 0
ys = 0
ax.scatter(xs, ys, fun1(np.array([xs, ys])), c='r', s=10)

fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
def fun2(arr) -> np.ndarray:
    # Booth Function
    x = arr[0]
    y = arr[1]
    return (x + 2 * y - 7) ** 2 + (2 * x + y - 5) ** 2

def draw_fun2(X, Y):
    return (X + 2 * Y - 7)**2 + (2 * X + Y - 5)**2

def grad_fun2(arr):
    x = arr[0]
    y = arr[1]
    return np.array([
        10 * x + 8 * y - 34,
        10 * y + 8 * x - 38
    ])

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-1, 2, 0.05)
Y = np.arange(1, 5, 0.05)
X, Y = np.meshgrid(X, Y)
Z = draw_fun2(X, Y)

surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, alpha=0.5)

xs = 1
ys = 3
ax.scatter(xs, ys, fun2(np.array([xs, ys])), c='r', s=10)

ax.view_init(30, -10, 0)

fig.colorbar(surf, shrink=0.3, aspect=3)

# %%
def fun3(arr) -> np.ndarray:
    # Mathias function
    x = arr[0]
    y = arr[1]
    return 0.26 * (x**2 + y ** 2) - 0.48 * x * y

def draw_fun3(X, Y):
    return 0.26 * (X ** 2 + Y ** 2) - 0.48 * X * Y

def grad_fun3(arr):
    x = arr[0]
    y = arr[1]
    return np.array([
        0.52 * x - 0.48 * y,
        0.52 * y - 0.48 * x
    ])

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-5, 5, 0.05)
Y = np.arange(-5, 5, 0.05)
X, Y = np.meshgrid(X, Y)
Z = draw_fun3(X, Y)

surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, alpha=0.5)

# ax.set_zlim(-1.01, 1.01)
# ax.zaxis.set_major_locator(LinearLocator(10))
xs = 0
ys = 0
print(fun3(np.array([xs, ys])))
ax.scatter(xs, ys, fun3(np.array([xs, ys])), c='r', s=10)


ax.view_init(45, 225, 0)

fig.colorbar(surf, shrink=0.3, aspect=3)
# Out:
# 0.0

# %%
def gradient_descent(g, start, lr, epoch = 100):
    previous_value = start
    for i in range(epoch):
        next_value = previous_value - lr * g(previous_value)
        previous_value = next_value
    return previous_value

# %%
print(gradient_descent(grad_fun1, np.array([10, 10]), 0.001, 100000))
# Out:
# [1.13273609e-86 1.13273609e-86]

# %%
print(gradient_descent(grad_fun2, np.array([10, 10]), 0.001, 100000))
# Out:
# [1. 3.]

# %%
print(gradient_descent(grad_fun3, np.array([10, 10]), 0.001, 1000000))
# Out:
# [4.24495684e-17 4.24495684e-17]
